        "300": {"basic": {"time": 1.29, "max_node": 1795}, "addition": {"time": 0.62, "max_node": 901}, "contraction": {"time": 0.80, "max_node": 600}},
        "400": {"basic": {"time": 2.03, "max_node": 2395}, "addition": {"time": 1.00, "max_node": 1201}, "contraction": {"time": 1.26, "max_node": 800}},
        "500": {"basic": {"time": 2.96, "max_node": 2995}, "addition": {"time": 1.45, "max_node": 1501}, "contraction": {"time": 1.72, "max_node": 1000}}
    },
    "QRW": {
        "15": {"basic": {"time": 36.86, "max_node": 13122}, "addition": {"time": 24.59, "max_node": 10882}, "contraction": {"time": 7.16, "max_node": 222}},
        "18": {"basic": {"time": 139.76, "max_node": 90538}, "addition": {"time": 84.69, "max_node": 37064}, "contraction": {"time": 11.23, "max_node": 226}},
        "20": {"basic": {"time": 341.05, "max_node": 265614}, "addition": {"time": 218.29, "max_node": 107714}, "contraction": {"time": 14.31, "max_node": 404}},
        "30": {"basic": {"time": None, "max_node": None}, "addition": {"time": None, "max_node": None}, "contraction": {"time": 36.82, "max_node": 404}},
        "50": {"basic": {"time": None, "max_node": None}, "addition": {"time": None, "max_node": None}, "contraction": {"time": 118.08, "max_node": 404}},
        "100": {"basic": {"time": None, "max_node": None}, "addition": {"time": None, "max_node": None}, "contraction": {"time": 692.08, "max_node": 436}}
    }
}

# %%
for exp_name in data.keys():
    qubits = [int(i) for  i in data[exp_name].keys()]
    times_basic, times_addition, times_contraction = [], [], []
    nodes_basic, nodes_addition, nodes_contraction = [], [], []

    for key, value in data[exp_name].items():
        print(value)
        for category in ['basic', 'addition', 'contraction']:
            times_list = locals()[f'times_{category}']
            nodes_list = locals()[f'nodes_{category}']
            times_list.append(value[category]['time'])
            nodes_list.append(value[category]['max_node'])
    plt.rcParams['lines.linewidth'] = 2.5
    plt.rcParams['font.size'] = 16
    plt.figure(figsize=(10, 6))
    plt.plot(qubits, times_basic, marker='o', label='Basic', linestyle='-')
    plt.plot(qubits, times_addition, marker='s', label='Addition', linestyle='--')
    plt.plot(qubits, times_contraction, marker='^', label='Contraction', linestyle='-.')

    plt.xticks(qubits)
    plt.xlabel(f"qubits number about {exp_name}")
    plt.ylabel('Time(seconds)')
    plt.xticks(rotation=45)
    plt.legend(loc = "lower right")
    for x in qubits:
        plt.axvline(x, color='grey', linestyle='-', linewidth=0.2)
    ax = plt.gca()
    ax.set_yscale('log')
    plt.tight_layout()

    # Show the plot
    plt.savefig(f"alg_{exp_name}_time.pdf")
    
    plt.figure(figsize=(10, 6))
    plt.plot(qubits, nodes_basic, marker='o', label='Basic', linestyle='-')
    plt.plot(qubits, nodes_addition, marker='s', label='Addition', linestyle='--')
    plt.plot(qubits, nodes_contraction, marker='^', label='Contraction', linestyle='-.')

    plt.xticks(qubits)
    plt.xlabel(f"qubits number about {exp_name}")
    
    plt.ylabel('Nodes')
    # plt.title('Comparison of Max Node Across Different Methods')
    plt.xticks(rotation=45)
    plt.legend(loc = "lower right")
    for x in qubits:
        plt.axvline(x, color='grey', linestyle='-', linewidth=0.2)
    ax = plt.gca()
    ax.set_yscale('log')
    plt.tight_layout()

    # Show the plot
    plt.savefig(f"alg_{exp_name}_node.pdf")
# Out:
# {'basic': {'time': 19.33, 'max_node': 15785}, 'addition': {'time': 17.35, 'max_node': 15099}, 'contraction': {'time': 1.61, 'max_node': 597}}
# {'basic': {'time': 76.47, 'max_node': 61694}, 'addition': {'time': 66.02, 'max_node': 60332}, 'contraction': {'time': 2.41, 'max_node': 516}}
# {'basic': {'time': 294.65, 'max_node': 243946}, 'addition': {'time': 259.87, 'max_node': 241240}, 'contraction': {'time': 4.39, 'max_node': 1036}}
# {'basic': {'time': None, 'max_node': None}, 'addition': {'time': None, 'max_node': None}, 'contraction': {'time': 2953.57, 'max_node': 851973}}
# {'basic': {'time': 34.64, 'max_node': 65536}, 'addition': {'time': 18.88, 'max_node': 32770}, 'contraction': {'time': 0.08, 'max_node': 63}}
# {'basic': {'time': 282.12, 'max_node': 524288}, 'addition': {'time': 148.13, 'max_node': 262146}, 'contraction': {'time': 0.1, 'max_node': 31}}
# ...

# %%
import matplotlib.pyplot as plt

# Sample data
categories = [f"{i}" for i in range(10,110,10)]
data_set_1 = [0.021735429763793945, 0.07045626640319824, 0.15208148956298828, 0.35424327850341797,0.4577300548553467,0.6504325866699219,1.0306131839752197,1.253345012664795,1.6272251605987549,2.0525026321411133]  # Replace with your first set of data
data_set_2 = [0.011281013488769531, 0.02047443389892578, 0.029601335525512695, 0.03786492347717285,0.04343891143798828,0.05319023132324219,0.06557989120483398,0.07190608978271484,0.0830075740814209,0.09486722946166992]  # Replace with your second set of data

# Creating the bar chart
fig, ax = plt.subplots()

# Set the width for each bar
bar_width = 0.35

# Positions of the left bar-boundaries
bar1 = [i for i in range(len(data_set_1))]

# Positions of the right bar-boundaries
bar2 = [i + bar_width for i in range(len(data_set_2))]

# Plotting both sets of data
ax.bar(bar1, data_set_1, width=bar_width, label='Python')
ax.bar(bar2, data_set_2, width=bar_width, label='C++')

# Adding labels and title
ax.set_xlabel('Qubits number about BV')
ax.set_ylabel('time')
# ax.set_title('Bar Chart Comparison')
ax.set_xticks([r + bar_width / 2 for r in range(len(data_set_1))])
ax.set_xticklabels(categories)
ax.legend()

# Display the plot
# plt.show()
plt.savefig(f"python_c.pdf")
